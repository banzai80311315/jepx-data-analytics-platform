# %% [raw]
# - data/raw/to_import/ に JEPX の CSV を置く
# - python -m batch.import_jepx_prices を実行する
# - CSV を読む
# - 受渡日 と 時刻コード から dt_start を作る
# - 各エリア列を縦持ちに変換する
# - areas テーブルから area_id を引く
# - jepx_prices に ON CONFLICT 付きで UPSERT する
# - 終わったファイルを data/raw/imported/ に移す
